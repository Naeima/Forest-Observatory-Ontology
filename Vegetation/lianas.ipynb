# %%
from rdflib import Graph, Literal, RDF, URIRef, Namespace 
from rdflib.namespace import FOAF , XSD, SSN, SOSA 
import urllib.parse
import pandas as pd 
import matplotlib.pylab as plt
from matplotlib import pyplot

# %%
df = pd.read_csv('lianas.csv')

# %%
df['ID1'] = df.index + 1

# %%
df
# Out:
#         Site_name  Plot_no Site_plot_code        Date  Tree_individual_no  \
# 0       Danum W15        1           F1P1  2017-07-21                   2
# 1       Danum W15        1           F1P1  2017-07-21                   2
# 2       Danum W15        1           F1P1  2017-07-21                   2
# 3       Danum W15        1           F1P1  2017-07-21                   3
# 4       Danum W15        1           F1P1  2017-07-21                   5
# ...           ...      ...            ...         ...                 ...
# 3065  Danum Malua        1          F18P1  2017-10-28                3893
# 3066  Danum Malua        1          F18P1  2017-10-28                3895
# 3067  Danum Malua        1          F18P1  2017-10-28                3895
# 3068  Danum Malua        1          F18P1  2017-10-28                3895
# 3069  Danum Malua        1          F18P1  2017-10-28                3895
#
#                  Tree_ID  Tree_dbh_cm  Tree_height_m  Tree_N_lianas  \
# 0      Shorea pauciflora        110.0           60.0              3
# 1      Shorea pauciflora        110.0           60.0              3
# 2      Shorea pauciflora        110.0           60.0              3
# 3               Syzygium         40.5            NaN              1
# 4               Syzygium         62.7            NaN              1
# ...                  ...          ...            ...            ...
# 3065              Shorea         15.0            NaN              4
# 3066  Macaranga gigantea         39.0           27.0              4
# 3067  Macaranga gigantea         39.0           27.0              4
# 3068  Macaranga gigantea         39.0           27.0              4
# 3069  Macaranga gigantea         39.0           27.0              4
#
#       Liana_dbh_cm Tree_notes  Subplot_radius_m   ID1
# 0             10.0        NaN                30     1
# 1              9.0        NaN                30     2
# 2              9.8        NaN                30     3
# 3              3.4        NaN                30     4
# 4              3.4        NaN                30     5
# ...            ...        ...               ...   ...
# 3065           2.3        NaN                20  3066
# 3066           5.0        NaN                30  3067
# 3067           2.5        NaN                30  3068
# 3068           3.5        NaN                30  3069
# 3069           4.0        NaN                30  3070
#
# [3070 rows x 13 columns]

# %%
df['ID'] ='lianas' + df['ID1'].astype(str)

# %%
df.tail(2)
# Out:
#         Site_name  Plot_no Site_plot_code        Date  Tree_individual_no  \
# 3068  Danum Malua        1          F18P1  2017-10-28                3895
# 3069  Danum Malua        1          F18P1  2017-10-28                3895
#
#                  Tree_ID  Tree_dbh_cm  Tree_height_m  Tree_N_lianas  \
# 3068  Macaranga gigantea         39.0           27.0              4
# 3069  Macaranga gigantea         39.0           27.0              4
#
#       Liana_dbh_cm Tree_notes  Subplot_radius_m   ID1          ID
# 3068           3.5        NaN                30  3069  lianas3069
# 3069           4.0        NaN                30  3070  lianas3070

# %%
g = Graph()
ID = Namespace('lianas_')
SOSA = Namespace('http://www.w3.org/ns/sosa/')
UNIT= Namespace('http://qudt.org/vocab/unit/')
schema = Namespace('http://schema.org/')
uri=URIRef('http://www.w3.org/2000/01/rdf-schema#')
OBSPRO= Namespace('http://www.w3.org/ns/sosa/ObservableProperty/')
FEATURE= Namespace('http://www.w3.org/ns/sosa/FeatureOfInterest/')
TIME = Namespace('http://www.w3.org/2006/time#')
VOID = Namespace('http://rdfs.org/ns/void#')
XMLNS = Namespace('http://www.w3.org/XML/1998/namespace')

# %%
for index, row in df.iterrows():
    g.add((URIRef(ID+row['ID']), RDF.type, SOSA.Observation))
    
    g.add((URIRef(ID+row['ID']), SOSA.Observation, Literal(row['ID'], datatype=XSD.string)))
    
    g.add((URIRef(ID+row['ID']), URIRef(schema+'lianas'), Literal(row['ID'], datatype=XSD.string) ))  
    
    g.add((URIRef(ID+row['ID']), schema.Site_name, Literal(row['Site_name'], datatype=XSD.string)))
  
    g.add((URIRef(ID+row['ID']), FEATURE.Plot_no, Literal(row['Plot_no'], datatype=XSD.integer)))

    g.add((URIRef(ID+row['ID']), schema.Site_plot_code, Literal(row['Site_plot_code'], datatype=XSD.string)))
    
    g.add((URIRef(ID+row['ID']), TIME.Date, Literal(row['Date'], datatype=XSD.date)))
    
    g.add((URIRef(ID+row['ID']), OBSPRO.Tree_individual_no, Literal(row['Tree_individual_no'], datatype=XSD.integer)))
    
    g.add((URIRef(ID+row['ID']), schema.Tree_ID	, Literal(row['Tree_ID'], datatype=XSD.string)))
    
    g.add((URIRef(ID+row['ID']), OBSPRO.Tree_dbh_cm, Literal(row['Tree_dbh_cm'], datatype=XSD.float)))
    
    g.add((URIRef(ID+row['ID']), OBSPRO.Tree_height_m, Literal(row['Tree_height_m'], datatype=XSD.float)))
    
    g.add((URIRef(ID+row['ID']), OBSPRO.Liana_dbh_cm, Literal(row['Liana_dbh_cm'], datatype=XSD.integer)))

    g.add((URIRef(ID+row['ID']), OBSPRO.Liana_dbh_cm, Literal(row['Liana_dbh_cm'], datatype=XSD.float)))
    
    g.add((URIRef(ID+row['ID']), schema.Tree_notes, Literal(row['Tree_notes'], datatype=XSD.string)))

    g.add((URIRef(ID+row['ID']), OBSPRO.Subplot_radius_m, Literal(row['Subplot_radius_m'], datatype=XSD.integer) ))

# %%
# print(g.serialize(format='turtle').decode('UTF-8'))

# %%
# saving ontology to disk
g.serialize('lianas.rdf', format='ttl')

# %%
# # Code to add data to stardog 
# import stardog

# conn_details = {
#   'endpoint': 'http://localhost:5820',
#   'username': 'admin',
#   'password': 'admin'
# }
# with stardog.Admin(**conn_details) as admin:
#     Aqeela = admin.new_database('Aqeela')

# conn = stardog.Connection('Aqeela', **conn_details)

# conn.begin()

# conn.add(
#     stardog.content.File('Aqeela.rdf', stardog.content_types.TURTLE),
# #     graph_uri=graph_uri)
# conn.commit()

# %%
# # Code to add data to stardog shared database  
# import stardog

# conn_details = {
#   'endpoint': 'https://stardog.cs.cf.ac.uk',
#   'username': 'c1887413',
#   'password': 'd5XPMny3epjcBgE'}

# conn = stardog.Connection('forest_observatory', **conn_details)

# conn.begin()

# conn.add(
#     stardog.content.File('SoilPro.rdf', stardog.content_types.TURTLE),

# conn.commit()
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_6232/1032307845.py", line 16
#     conn.commit()
#                  ^
# SyntaxError: unexpected EOF while parsing
