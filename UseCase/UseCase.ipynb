# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro
import scipy.stats as stats
from scipy.stats import mannwhitneyu

# %%
# Reading in observations files

df= pd.read_csv("CQ3.csv")

# %%
# Evaluation Three dataframe 
df.describe().round(2)
# Out:
#        No-Rule    SWRL
# count    50.00   50.00
# mean    262.30  202.84
# std      47.14   18.01
# min     205.00  150.00
# 25%     232.00  192.00
# 50%     244.50  199.00
# 75%     268.25  210.00
# max     390.00  267.00

# %%
# Evaluation Three line graph 
sns.lineplot(data=df, color= "navy")
plt.xlabel("Queries Count")
plt.ylabel("Response Time (ms)")
# Out:
# Text(0, 0.5, 'Response Time (ms)')
